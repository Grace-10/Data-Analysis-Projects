# %% [markdown]
# # My Jupyter notebook on IBM Watson Studio

# %% [markdown]
# ###### AKINDOYIN GRACE OLAJUMOKE
# I am currently a student data analyst

# %% [markdown]
# I am interested in data science because i want to be able to solve problems that might arise in different industries like the financial industry.

# %% [markdown]
# The following codes is to change an integer into a float

# %%
num=6
new_num = float(num)
print(new_num)
# Out:
# 6.0

# %% [markdown]
# www.ibm.com
#
# 1. Apple
# 2. Ball
# 3. Code
# 4. Markdown
